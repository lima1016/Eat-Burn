# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.models import resnet50, ResNet50_Weights

# weights 파라미터를 사용하여 사전 학습된 모델 로드 (권장 방식)
weights = ResNet50_Weights.IMAGENET1K_V1  # 또는 ResNet50_Weights.DEFAULT
model = resnet50(weights=weights)


# -------------------------------
# 1. 커스텀 데이터셋 정의
# -------------------------------
class KFoodDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): kfood 최상위 폴더 경로 (하위에 여러 단계 폴더가 있음)
            transform (callable, optional): 이미지에 적용할 변환 함수
        """
        self.image_paths = []
        self.labels = []
        self.transform = transform
        self.classes = set()

        # 최상위 폴더부터 재귀적으로 모든 이미지 파일 탐색
        for root, dirs, files in os.walk(root_dir):
            for file in files:
                if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    # 마지막 폴더 이름을 라벨로 사용합니다.
                    label = os.path.basename(root)
                    path = os.path.join(root, file)
                    self.image_paths.append(path)
                    self.labels.append(label)
                    self.classes.add(label)

        # 클래스 목록 정렬 후, 클래스 이름 -> 인덱스 매핑 생성
        self.classes = sorted(list(self.classes))
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        # 문자열 라벨을 인덱스로 변환
        self.labels = [self.class_to_idx[label] for label in self.labels]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        img = Image.open(self.image_paths[index]).convert("RGB")
        if self.transform:
            img = self.transform(img)
        label = self.labels[index]
        return img, label


# -------------------------------
# 2. 하이퍼파라미터 및 설정
# -------------------------------
BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 0.001

# kfood 최상위 폴더 경로만 지정
kfood_dir = "C:/Users/kimyo/Downloads/kfood"  # 실제 경로로 수정하세요

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------------
# 3. 데이터 전처리(transform) 정의
# -------------------------------
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

transform_val = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# -------------------------------
# 4. 데이터셋 및 DataLoader 구성
# -------------------------------
dataset = KFoodDataset(root_dir=kfood_dir, transform=transform_train)
# 전체 데이터를 8:2 비율로 분리 (예시)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Windows 환경에서는 num_workers=0 또는 main guard를 사용해야 합니다.
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

NUM_CLASSES = len(dataset.classes)
print(f"Number of classes: {NUM_CLASSES}")
print(f"Total dataset size: {len(dataset)} images")
print(f"Train dataset size: {train_size} images")
print(f"Validation dataset size: {val_size} images")

# -------------------------------
# 5. ResNet 모델 구성 (마지막 fc layer 재정의)
# -------------------------------
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, NUM_CLASSES)  # 마지막 출력층 재정의
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)


# -------------------------------
# 6. 학습 및 검증 함수 정의
# -------------------------------
def train_epoch(model, dataloader, criterion, optimizer, epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total
    print(f"Epoch {epoch + 1} - Train Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")


def validate_epoch(model, dataloader, criterion, epoch):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total
    print(f"Epoch {epoch + 1} - Validation Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")
    return epoch_loss


# -------------------------------
# 7. 모델 학습 실행
# -------------------------------
if __name__ == '__main__':
    best_loss = float("inf")
    for epoch in range(EPOCHS):
        train_epoch(model, train_loader, criterion, optimizer, epoch)
        val_loss = validate_epoch(model, val_loader, criterion, epoch)

        # 검증 손실이 개선되면 모델 저장
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save(model.state_dict(), "best_resnet50_kfood.pth")
            print(f"Saved best model at epoch {epoch + 1}")

    print("Training completed!")

# %%
import os
import requests
import json
import pandas as pd

# Azure Custom Vision API 정보
PREDICTION_KEY = "6XRfesg0Ka3EwuWvdx1MuMY9gGij25QJP3eoMKC7OGPQOtl9EojMJQQJ99BBACi0881XJ3w3AAAIACOGENeY"
PROJECT_ID = "bacf31b3-a6f7-40fd-8357-23aace5429cd"
ITERATION_NAME = "Iteration1"
ENDPOINT = "https://foodnamepredict-prediction.cognitiveservices.azure.com"

# API 엔드포인트 URL 설정
PREDICTION_URL = f"{ENDPOINT}/customvision/v3.0/Prediction/{PROJECT_ID}/classify/iterations/{ITERATION_NAME}/image"

# 테스트할 이미지 절대 경로로 변경 (Windows)
image_path = "Img_010_0021.jpg"

# 파일 존재 확인
if not os.path.exists(image_path):
    print(f"파일을 찾을 수 없습니다: {image_path}")
    exit()  # 프로그램 종료

# 요청 헤더 설정
headers = {
    "Prediction-Key": PREDICTION_KEY,
    "Content-Type": "application/octet-stream"
}

# API 호출
with open(image_path, "rb") as image_file:
    response = requests.post(PREDICTION_URL, headers=headers, data=image_file)

# API 응답을 JSON으로 변환
result = response.json()

# JSON 응답 출력 (Pretty Print)
print("JSON:")
print(json.dumps(result, indent=4))

# 예측 결과가 있는지 확인 후, 가장 높은 확률을 가진 태그 선택
if "predictions" in result and len(result["predictions"]) > 0:
    best_prediction = max(result["predictions"], key=lambda x: x["probability"])

    # 바로 사용 가능한 값으로 저장
    predicted_tag = best_prediction["tagName"]
    confidence_score = best_prediction["probability"] * 100  # 0.92 → 92.0%

    # CSV 파일 로드 (칼로리 정보를 가져오기 위해)
    CSV_FILE_PATH = "250218 한국음식 데이터 합본.csv"

    try:
        df = pd.read_csv(CSV_FILE_PATH)
    except Exception as e:
        print(f"CSV 파일 로드 오류: {e}")
        exit()

    # 예측된 음식명과 일치하는 칼로리 값 찾기
    matched_row = df[df['통합_식품명'] == predicted_tag]

    if not matched_row.empty:
        calories = matched_row.iloc[0]['1인당Cal']  # 첫 번째 일치 행의 칼로리 값
    else:
        calories = "데이터 없음"

    # 결과 출력
    print(f"\n예측 결과:")
    print(f"음식 이름: {predicted_tag}")
    print(f"신뢰도: {confidence_score:.2f}%")
    print(f"칼로리: {calories}")
else:
    print("\n예측 결과를 찾을 수 없습니다.")

# %%
import os
import requests
import json
import pandas as pd
import torch

# Azure Custom Vision API 정보
PREDICTION_KEY = "6XRfesg0Ka3EwuWvdx1MuMY9gGij25QJP3eoMKC7OGPQOtl9EojMJQQJ99BBACi0881XJ3w3AAAIACOGENeY"
PROJECT_ID = "bacf31b3-a6f7-40fd-8357-23aace5429cd"
ITERATION_NAME = "Iteration1"
ENDPOINT = "https://foodnamepredict-prediction.cognitiveservices.azure.com"

# API 엔드포인트 URL 설정
PREDICTION_URL = f"{ENDPOINT}/customvision/v3.0/Prediction/{PROJECT_ID}/classify/iterations/{ITERATION_NAME}/image"

# 테스트할 이미지 절대 경로로 변경 (Windows)
image_path = "Img_010_0021.jpg"

# 파일 존재 확인
if not os.path.exists(image_path):
    print(f"파일을 찾을 수 없습니다: {image_path}")
    exit()  # 프로그램 종료

# 요청 헤더 설정
headers = {
    "Prediction-Key": PREDICTION_KEY,
    "Content-Type": "application/octet-stream"
}

# API 호출
with open(image_path, "rb") as image_file:
    response = requests.post(PREDICTION_URL, headers=headers, data=image_file)

# API 응답을 JSON으로 변환
result = response.json()

# JSON 응답 출력 (Pretty Print)
print("JSON:")
print(json.dumps(result, indent=4))

# 예측 결과가 있는지 확인 후, 가장 높은 확률을 가진 태그 선택
if "predictions" in result and len(result["predictions"]) > 0:
    best_prediction = max(result["predictions"], key=lambda x: x["probability"])

    # 바로 사용 가능한 값으로 저장
    predicted_tag = best_prediction["tagName"]
    confidence_score = best_prediction["probability"] * 100  # 0.92 → 92.0%

    # CSV 파일 로드 (칼로리 정보를 가져오기 위해)
    CSV_FILE_PATH = "250218 한국음식 데이터 합본.csv"

    try:
        food_data = pd.read_csv(CSV_FILE_PATH)
    except Exception as e:
        print(f"CSV 파일 로드 오류: {e}")
        exit()

    # 예측된 음식명과 일치하는 칼로리 값 찾기
    matched_row = food_data[food_data['통합_식품명'] == predicted_tag]

    if not matched_row.empty:
        input_calories = matched_row.iloc[0]['1인당Cal']  # 첫 번째 일치 행의 칼로리 값
    else:
        input_calories = "데이터 없음"

    # 운동 데이터 CSV 로드
    exercise_data = pd.read_csv("운동데이터_송부.csv")

    # 필요한 칼럼만 선택
    exercise_data = exercise_data[['운동이름', '칼로리(1분)', '종류']]

    # 음식이 데이터에 존재하지 않거나 칼로리 값이 "데이터 없음"인 경우
    if input_calories == "데이터 없음":
        print("❌ 해당 음식의 칼로리 데이터를 찾을 수 없습니다.")
    else:
        # 운동 추천: 섭취한 칼로리를 소모할 수 있는 운동 리스트 계산
        exercise_data['운동시간(분)'] = input_calories / exercise_data['칼로리(1분)']

        # 운동 추천 리스트 출력
        print(f"✅ '{predicted_tag}' (섭취 칼로리: {input_calories} kcal)을 소모하려면:")
        print(exercise_data[['운동이름', '운동시간(분)']].sort_values(by='운동시간(분)').head(5))  # 상위 5개 운동 추천
else:
    print("\n예측 결과를 찾을 수 없습니다.")
# Out:
# JSON:
# {
#     "id": "71586106-33c1-4d85-a10c-62e946687f1c",
#     "project": "bacf31b3-a6f7-40fd-8357-23aace5429cd",
#     "iteration": "ecfea1fb-a60e-447a-bdff-9be4621b91b1",
#     "created": "2025-02-20T01:42:33.309Z",
#     "predictions": [
#         {
#             "probability": 0.85196537,
#             "tagId": "81104f2d-b0a7-480d-bbd6-ead4acc0ba76",
#             "tagName": "\uc870\uac1c\uad6c\uc774"
#         },
#         {
#             "probability": 0.03253507,
#             "tagId": "55b3fb91-4964-4f69-8f02-a00cbdbd191d",
#             "tagName": "\uac04\uc7a5\uac8c\uc7a5"
#         },
#         {
#             "probability": 0.024168639,
#             "tagId": "5bf9156b-8c25-484c-8d51-eeab92ce3693",
#             "tagName": "\uaf2c\ub9c9\ucc1c"
#         },
#         {
#             "probability": 0.01295535,
#             "tagId": "87bc367f-d7d5-4ac0-87cc-9f4d0c3e4d16",
#             "tagName": "\uc0b0\ub099\uc9c0"
#         },
#         {
#             "probability": 0.008482886,
#             "tagId": "8451629a-39f9-4df0-9860-bfab927b7add",
#             "tagName": "\uc8fc\uba39\ubc25"
#         },
#         {
#             "probability": 0.005474866,
#             "tagId": "b1161a33-b9cf-4f58-89e7-af0c018a371f",
#             "tagName": "\uc21c\ub300"
#         },
#         {
#             "probability": 0.0038207623,
#             "tagId": "7bd0d483-69eb-49b9-898a-65f6f885a5c2",
#             "tagName": "\uc720\ubd80\ucd08\ubc25"
#         },
#         {
#             "probability": 0.0037775422,
#             "tagId": "c646ea7f-bb3d-4d17-ab94-6e5763a68401",
#             "tagName": "\ud638\ubc15\uc804"
#         },
#         {
#             "probability": 0.0028032342,
#             "tagId": "9721312b-bf9c-4510-a282-d486f403302f",
#             "tagName": "\uac00\uc9c0\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.002349576,
#             "tagId": "53ac082a-ba15-4c6f-8877-76a6583b9bfe",
#             "tagName": "\uba4d\uac8c"
#         },
#         {
#             "probability": 0.002170575,
#             "tagId": "0795d64f-5647-4679-9bc6-0c00db14d5ac",
#             "tagName": "\ubb3c\ud68c"
#         },
#         {
#             "probability": 0.0020309805,
#             "tagId": "4a1d922e-57cd-4adc-acc7-13c47ff9ea12",
#             "tagName": "\ud3b8\uc721"
#         },
#         {
#             "probability": 0.0019514675,
#             "tagId": "098f2b2e-5304-421d-b12e-9bbad187ba09",
#             "tagName": "\uacf1\ucc3d\uc804\uace8"
#         },
#         {
#             "probability": 0.0019025876,
#             "tagId": "b453f6d0-05e7-4b5d-b020-d23a1565e227",
#             "tagName": "\uacf1\ucc3d\uad6c\uc774"
#         },
#         {
#             "probability": 0.0018264239,
#             "tagId": "fde5cf58-4c52-4e70-b326-07e9f7475a3f",
#             "tagName": "\uc218\uc81c\ube44"
#         },
#         {
#             "probability": 0.0015767959,
#             "tagId": "4ea16d9b-90d1-4363-beec-b44192855b74",
#             "tagName": "\uac10\uc790\uc804"
#         },
#         {
#             "probability": 0.0015526676,
#             "tagId": "25e122d0-e380-4fbe-bcde-c6e62c08cd8f",
#             "tagName": "\ud53c\uc790"
#         },
#         {
#             "probability": 0.0015272391,
#             "tagId": "610e35f3-f458-48b6-94e3-99f6cab9c008",
#             "tagName": "\ub9cc\ub450"
#         },
#         {
#             "probability": 0.0012421595,
#             "tagId": "0cac99b3-8128-4bea-ad4b-24d8b852df82",
#             "tagName": "\uc57d\uacfc"
#         },
#         {
#             "probability": 0.0011628555,
#             "tagId": "bdbb62f7-224d-4899-85f8-19f53e0d2141",
#             "tagName": "\uc218\uc721"
#         },
#         {
#             "probability": 0.0009997484,
#             "tagId": "f9b686b9-19c3-4a11-aef8-d4f8e7fab8ec",
#             "tagName": "\uace0\ucd94\ud280\uae40"
#         },
#         {
#             "probability": 0.0009697682,
#             "tagId": "59e4ab4c-90e3-4f1a-a074-e81a40be3a18",
#             "tagName": "\ub204\ub8fd\uc9c0"
#         },
#         {
#             "probability": 0.0009341913,
#             "tagId": "ac0ece83-46ca-4363-a9aa-7ae07a037c28",
#             "tagName": "\ub5a1\uac08\ube44"
#         },
#         {
#             "probability": 0.0009323253,
#             "tagId": "ccb25c57-0cce-4f07-8ed6-2b9832d1b8dd",
#             "tagName": "\uc624\uc9d5\uc5b4\ud280\uae40"
#         },
#         {
#             "probability": 0.0008744207,
#             "tagId": "4085c64b-7732-433d-8987-e5fc2928d61b",
#             "tagName": "\uc57d\uc2dd"
#         },
#         {
#             "probability": 0.0008213736,
#             "tagId": "0b551c73-2b5c-4457-8856-b85fdf368251",
#             "tagName": "\uc871\ubc1c"
#         },
#         {
#             "probability": 0.000809355,
#             "tagId": "95c49332-0611-4cf7-bbc6-50eb38c6f8d2",
#             "tagName": "\uac08\uce58\uad6c\uc774"
#         },
#         {
#             "probability": 0.0008018214,
#             "tagId": "1109b2ab-9966-47b5-84a6-3a5498cbb982",
#             "tagName": "\uc0bc\uacb9\uc0b4"
#         },
#         {
#             "probability": 0.0007876953,
#             "tagId": "70bafc48-9d69-484d-b871-42db8a2f3a96",
#             "tagName": "\uc0bc\uacc4\ud0d5"
#         },
#         {
#             "probability": 0.0007855505,
#             "tagId": "bff3ada9-04a6-4c8a-a910-c6f22e3ee4ba",
#             "tagName": "\uac08\ube44\ud0d5"
#         },
#         {
#             "probability": 0.0007225379,
#             "tagId": "2a759315-4cb4-45ad-a08b-56d4b93ea677",
#             "tagName": "\ud6c8\uc81c\uad6c"
#         },
#         {
#             "probability": 0.00072122336,
#             "tagId": "91624b3d-f491-4c0c-9576-ad244c7b8657",
#             "tagName": "\ub3d9\uadf8\ub791\ub561"
#         },
#         {
#             "probability": 0.0006711837,
#             "tagId": "44199d1d-091a-46d0-974b-dbba2b39a134",
#             "tagName": "\ubcf4\uc308"
#         },
#         {
#             "probability": 0.0006560557,
#             "tagId": "7611f3b7-270a-49d7-a41a-fa90fca3fd80",
#             "tagName": "\ucb48\uafb8\ubbf8\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.00063962693,
#             "tagId": "eef3ef1c-3ca0-49dc-ad59-853c9cd75636",
#             "tagName": "\ub3d9\ud0dc\ucc0c\uac1c"
#         },
#         {
#             "probability": 0.0006312133,
#             "tagId": "c5daef2c-51db-4806-9837-9013495216da",
#             "tagName": "\ubc31\uae40\uce58"
#         },
#         {
#             "probability": 0.00062422635,
#             "tagId": "a83c769a-7c16-4ba7-90d5-8086851f9a0a",
#             "tagName": "\uc1a1\ud3b8"
#         },
#         {
#             "probability": 0.0006185725,
#             "tagId": "801e78c9-d0b0-48e9-afaa-8729de585eb3",
#             "tagName": "\uac10\uc790\ud0d5"
#         },
#         {
#             "probability": 0.0005971194,
#             "tagId": "1a3b1e2a-9b23-43c2-86b2-d88dd48bfa71",
#             "tagName": "\uc0c8\uc6b0\ud280\uae40"
#         },
#         {
#             "probability": 0.0005941273,
#             "tagId": "c0ea2dc8-b4f4-48a1-839c-19fa1a8b5acf",
#             "tagName": "\uacc4\ub780\ub9d0\uc774"
#         },
#         {
#             "probability": 0.0005940236,
#             "tagId": "9fbae920-9fcb-4361-b360-db1ffbfdd94f",
#             "tagName": "\uc560\ud638\ubc15\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.0005786815,
#             "tagId": "345dc76d-64df-497d-b9ad-f435af24081c",
#             "tagName": "\ub450\ubd80\uae40\uce58"
#         },
#         {
#             "probability": 0.00057676574,
#             "tagId": "0a92ccdd-7c73-4805-8ea8-e030a4b22995",
#             "tagName": "\uc804\ubcf5\uc8fd"
#         },
#         {
#             "probability": 0.0005613217,
#             "tagId": "794b709a-05e6-4547-9f68-a371c7081c0e",
#             "tagName": "\uaf41\uce58\uc870\ub9bc"
#         },
#         {
#             "probability": 0.0005346407,
#             "tagId": "022ada49-ca01-428d-8382-da8afc5ac9a8",
#             "tagName": "\uac08\ube44\uad6c\uc774"
#         },
#         {
#             "probability": 0.000526635,
#             "tagId": "4fdccf4c-3016-466d-a707-ccfabcc549fb",
#             "tagName": "\uc0dd\uc120\uc804"
#         },
#         {
#             "probability": 0.000459002,
#             "tagId": "139b513d-d6ed-443a-b6bd-33037d8167de",
#             "tagName": "\ub450\ubd80\uc870\ub9bc"
#         },
#         {
#             "probability": 0.00044526072,
#             "tagId": "31469af3-8025-47e6-9829-3aab4236c152",
#             "tagName": "\uc870\uae30\uad6c\uc774"
#         },
#         {
#             "probability": 0.0004149697,
#             "tagId": "081971bb-9d0b-4c42-b7b0-84ffd3d25886",
#             "tagName": "\ud30c\uc804"
#         },
#         {
#             "probability": 0.000414796,
#             "tagId": "a0fbf1a4-fec7-4683-abf6-827e79fbe6cc",
#             "tagName": "\uc7a5\uc5b4\uad6c\uc774"
#         },
#         {
#             "probability": 0.00040553111,
#             "tagId": "8933f3f3-56b4-4abf-b943-f71c01817db8",
#             "tagName": "\uce7c\uad6d\uc218"
#         },
#         {
#             "probability": 0.0003933308,
#             "tagId": "edfaa5d5-095b-41e6-9899-f33d1c069cb3",
#             "tagName": "\ubc30\ucd94\uae40\uce58"
#         },
#         {
#             "probability": 0.00035488466,
#             "tagId": "7384a73d-d5e7-45e6-af38-c8d724ffcedf",
#             "tagName": "\ucf54\ub2e4\ub9ac\uc870\ub9bc"
#         },
#         {
#             "probability": 0.00035000767,
#             "tagId": "62045dd8-0fb1-47eb-8b9f-ea53d49efef5",
#             "tagName": "\ud68c\ubb34\uce68"
#         },
#         {
#             "probability": 0.0003397477,
#             "tagId": "fb5fc185-dd70-43ab-8769-62ba57556dac",
#             "tagName": "\uc794\uce58\uad6d\uc218"
#         },
#         {
#             "probability": 0.00032969948,
#             "tagId": "236b1d2f-5ee7-46e3-bc54-0a80d4b44b22",
#             "tagName": "\uacbd\ub2e8"
#         },
#         {
#             "probability": 0.00032663715,
#             "tagId": "b1d285ec-4bd6-41ae-b7eb-40bbc1138a2f",
#             "tagName": "\ud6c4\ub77c\uc774\ub4dc\uce58\ud0a8"
#         },
#         {
#             "probability": 0.00032255444,
#             "tagId": "5de90f85-a229-4a91-a3c0-84c08c4354b0",
#             "tagName": "\uc54c\ubc25"
#         },
#         {
#             "probability": 0.0003192942,
#             "tagId": "d46b6bc5-9e6f-449f-8217-977b201971c8",
#             "tagName": "\ub098\ubc15\uae40\uce58"
#         },
#         {
#             "probability": 0.0003089371,
#             "tagId": "503672bf-b32c-4c7f-a086-c98c1412cab0",
#             "tagName": "\uacc4\ub780\ud6c4\ub77c\uc774"
#         },
#         {
#             "probability": 0.00029794787,
#             "tagId": "1e7f6743-1cd7-49f0-b8f4-27c0fd54fb1b",
#             "tagName": "\uc7a1\ucc44"
#         },
#         {
#             "probability": 0.00028865528,
#             "tagId": "8695ac84-f351-4783-99d3-acfc6e8b3eab",
#             "tagName": "\uafc0\ub5a1"
#         },
#         {
#             "probability": 0.00028842138,
#             "tagId": "2b0e186c-a7cb-49ad-8993-618e95e96133",
#             "tagName": "\uacf0\ud0d5\uc124\ub801\ud0d5"
#         },
#         {
#             "probability": 0.00028069512,
#             "tagId": "02dceda9-b879-4923-b317-e034c698bba0",
#             "tagName": "\ucc1c\ub2ed"
#         },
#         {
#             "probability": 0.00028031337,
#             "tagId": "2dc86d8f-d7e5-4a72-a332-1968ffd7ccb9",
#             "tagName": "\uc591\ub150\uce58\ud0a8"
#         },
#         {
#             "probability": 0.00027742572,
#             "tagId": "a8ed783c-60f7-4d67-859d-f3d2d457d927",
#             "tagName": "\uace0\ub4f1\uc5b4\uad6c\uc774"
#         },
#         {
#             "probability": 0.0002693576,
#             "tagId": "9e7c8671-66ae-4188-a114-f88f2693c2dc",
#             "tagName": "\ub2ed\uac08\ube44"
#         },
#         {
#             "probability": 0.0002635861,
#             "tagId": "c2d49a45-63ac-4787-a776-06a480da1187",
#             "tagName": "\uc9dc\uc7a5\uba74"
#         },
#         {
#             "probability": 0.0002477317,
#             "tagId": "53bb0543-5fc0-4d8d-969c-0ba79a25dbe9",
#             "tagName": "\ucf69\uad6d\uc218"
#         },
#         {
#             "probability": 0.00024296378,
#             "tagId": "b77d41fc-3785-45a1-a3ae-d3659a72a3ba",
#             "tagName": "\uae40\uce58\uc804"
#         },
#         {
#             "probability": 0.00022838837,
#             "tagId": "c1a8ec5a-2451-4bbd-ac9b-9baa3e26d8db",
#             "tagName": "\uc7a5\uc870\ub9bc"
#         },
#         {
#             "probability": 0.00022518141,
#             "tagId": "aa2ee0d1-acd2-409f-b10e-898d9bf06486",
#             "tagName": "\ud574\ubb3c\ucc1c"
#         },
#         {
#             "probability": 0.00021544869,
#             "tagId": "0099c940-998e-4c5b-a95d-727d5fafcadc",
#             "tagName": "\ubbf8\uc5ed\uc904\uae30\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.00021494484,
#             "tagId": "48ff16b3-7981-4a5a-bf9c-2f9f11fd2369",
#             "tagName": "\uc219\uc8fc\ub098\ubb3c"
#         },
#         {
#             "probability": 0.00021223209,
#             "tagId": "7ae6f194-ebaa-48e0-a329-cc45738fa78b",
#             "tagName": "\ub41c\uc7a5\ucc0c\uac1c"
#         },
#         {
#             "probability": 0.00020567571,
#             "tagId": "6be260df-7f5d-4e0d-b9b1-33f5fad37aa1",
#             "tagName": "\uc591\ub150\uac8c\uc7a5"
#         },
#         {
#             "probability": 0.00020514717,
#             "tagId": "afaef487-493e-46a2-8f09-be8b651888da",
#             "tagName": "\uc0c8\uc6b0\ubcf6\uc74c\ubc25"
#         },
#         {
#             "probability": 0.0002027177,
#             "tagId": "90c21338-cc9e-49d1-b608-ec9ecdf34d94",
#             "tagName": "\uc5b4\ubb35\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.00019958113,
#             "tagId": "6c15c155-dd30-4708-bf57-bba6aa7f3d5f",
#             "tagName": "\ub3c4\ud1a0\ub9ac\ubb35"
#         },
#         {
#             "probability": 0.00019495524,
#             "tagId": "f8998a4b-88f5-4a7a-ab91-084dd4b62719",
#             "tagName": "\uc218\uc815\uacfc"
#         },
#         {
#             "probability": 0.00018578896,
#             "tagId": "3265745e-99f9-46c6-8941-f53f865baf11",
#             "tagName": "\ubb3c\ub0c9\uba74"
#         },
#         {
#             "probability": 0.0001824596,
#             "tagId": "9c431f03-c1b4-4499-851b-88f33de364aa",
#             "tagName": "\ucf69\uc790\ubc18"
#         },
#         {
#             "probability": 0.00018204279,
#             "tagId": "a9e17c63-b984-4acc-8dda-c45105ec8083",
#             "tagName": "\ucd94\uc5b4\ud0d5"
#         },
#         {
#             "probability": 0.0001819411,
#             "tagId": "1a2c11ac-5101-4b02-893a-06967fc38833",
#             "tagName": "\uac74\uc0c8\uc6b0\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.0001756825,
#             "tagId": "ebf16a91-d50d-4220-9673-5373068b47fe",
#             "tagName": "\ubd88\uace0\uae30"
#         },
#         {
#             "probability": 0.00017326999,
#             "tagId": "f32f96d7-3cb0-486f-8803-a467c6ee8191",
#             "tagName": "\ud55c\uacfc"
#         },
#         {
#             "probability": 0.00017262064,
#             "tagId": "c852f3b8-96c1-4d5b-941f-d8157f439ff9",
#             "tagName": "\ub354\ub355\uad6c\uc774"
#         },
#         {
#             "probability": 0.00017123713,
#             "tagId": "36aaa1e3-9b3f-4c81-a659-d0c11805bfd8",
#             "tagName": "\uace0\ub4f1\uc5b4\uc870\ub9bc"
#         },
#         {
#             "probability": 0.0001704692,
#             "tagId": "f23eb88f-fee7-4585-9be1-8d54ec06ba0c",
#             "tagName": "\uc5f0\uadfc\uc870"
#         },
#         {
#             "probability": 0.00016752568,
#             "tagId": "780803d9-1e08-4c1e-b8d3-02839fc7ae8d",
#             "tagName": "\ub9c9\uad6d\uc218"
#         },
#         {
#             "probability": 0.00016632269,
#             "tagId": "d7e8ba57-91f7-4c8e-bb3e-d53c0ab86f49",
#             "tagName": "\uae4d\ub450\uae30"
#         },
#         {
#             "probability": 0.00015990993,
#             "tagId": "d4d3ebc1-ec89-47f2-8d13-cc613f14ba83",
#             "tagName": "\uc2dd\ud61c"
#         },
#         {
#             "probability": 0.00015894539,
#             "tagId": "8fd641bd-936c-470c-a6af-31fbf165e5d0",
#             "tagName": "\uc9ec\ubf55"
#         },
#         {
#             "probability": 0.00015501589,
#             "tagId": "c9e3ae4a-c225-4ad4-8430-d9dec5106b71",
#             "tagName": "\ub2ed\ubcf6\uc74c\ud0d5"
#         },
#         {
#             "probability": 0.00015487375,
#             "tagId": "7861ed8c-867f-4d2d-bcbc-b95810a75539",
#             "tagName": "\ud669\ud0dc\uad6c\uc774"
#         },
#         {
#             "probability": 0.00014917404,
#             "tagId": "1a229039-5bd7-4f65-856f-a6e83f71c665",
#             "tagName": "\uc885\uac01\uae40\uce58"
#         },
#         {
#             "probability": 0.0001472717,
#             "tagId": "d46951a6-e310-4a6f-96bb-7955427cb5f4",
#             "tagName": "\uc624\uc774\uc18c\ubc15\uc774"
#         },
#         {
#             "probability": 0.0001456616,
#             "tagId": "464d8d07-845e-4d68-a4d5-c7334e23e30e",
#             "tagName": "\ud64d\uc5b4\ubb34\uce68"
#         },
#         {
#             "probability": 0.00014537558,
#             "tagId": "dbc78a0b-020a-4a68-a9ca-cb3de3a206d6",
#             "tagName": "\uae7b\uc78e\uc7a5\uc544\ucc0c"
#         },
#         {
#             "probability": 0.00013956148,
#             "tagId": "6978d728-a73d-4d58-a0f7-a9ef3515bc87",
#             "tagName": "\uba78\uce58\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.00013158236,
#             "tagId": "ea9609ef-5309-4e30-8ecb-afee37fd524b",
#             "tagName": "\uc721\ud68c"
#         },
#         {
#             "probability": 0.00013025691,
#             "tagId": "cbbcc978-9bd6-4524-88d8-0091a5d0fd50",
#             "tagName": "\uae40\uce58\ubcf6\uc74c\ubc25"
#         },
#         {
#             "probability": 0.00012320733,
#             "tagId": "24d37b35-73b3-478d-88f7-5b390449fdb1",
#             "tagName": "\uc7a1\uace1\ubc25"
#         },
#         {
#             "probability": 0.000109547764,
#             "tagId": "97836452-6e37-412f-837c-0840f0dbf014",
#             "tagName": "\ub9e4\uc6b4\ud0d5"
#         },
#         {
#             "probability": 0.000108472406,
#             "tagId": "fd9dc9bf-125e-4038-991b-7332de1c5c66",
#             "tagName": "\uac10\uc790\uc870\ub9bc"
#         },
#         {
#             "probability": 0.00010647871,
#             "tagId": "df087d1f-809e-4e00-ae80-5136347e35e8",
#             "tagName": "\uace0\uc0ac\ub9ac\ub098\ubb3c"
#         },
#         {
#             "probability": 0.000105222825,
#             "tagId": "bc40f6ce-5a37-40eb-bb0f-1fc92bb486e7",
#             "tagName": "\ub545\ucf69\uc870\ub9bc"
#         },
#         {
#             "probability": 0.00010451665,
#             "tagId": "565be83b-0887-4b2a-9276-47db26abda93",
#             "tagName": "\uc81c\uc721\ubcf6\uc74c"
#         },
#         {
#             "probability": 0.00010412596,
#             "tagId": "3cab272d-a5c4-4c39-85f0-2d4349423408",
#             "tagName": "\ud638\ubc15\uc8fd"
#         },
#         {
#             "probability": 0.000100896556,
#             "tagId": "b6b0676c-474b-4c85-a1f4-c452b0afbc9e",
#             "tagName": "\uac08\ube44\ucc1c"
#         },
#         {
#             "probability": 9.547621e-05,
#             "tagId": "54383cf9-25ce-48f8-b64c-50719a1fd1f6",
#             "tagName": "\ud30c\uae40\uce58"
#         },
#         {
#             "probability": 9.258524e-05,
#             "tagId": "813f229d-aa29-4f9f-bf1e-236b3d2134b9",
#             "tagName": "\uc2dc\uae08\uce58\ub098\ubb3c"
#         },
#         {
#             "probability": 9.158856e-05,
#             "tagId": "24c35017-b18b-4294-b11e-d8a84de29bc2",
#             "tagName": "\uba54\ucd94\ub9ac\uc54c\uc870\ub9bc"
#         },
#         {
#             "probability": 8.70029e-05,
#             "tagId": "3787a06e-3367-428e-bf39-8b8b62bfe701",
#             "tagName": "\uc5f4\ubb34\uae40\uce58"
#         },
#         {
#             "probability": 8.252161e-05,
#             "tagId": "c7231388-90c5-4157-813b-320c79b5667f",
#             "tagName": "\uacfc\uba54\uae30"
#         },
#         {
#             "probability": 8.060616e-05,
#             "tagId": "2e54f9a3-c8b3-4da3-b170-6137960afaf0",
#             "tagName": "\ub5a1\ubcf6\uc774"
#         },
#         {
#             "probability": 8.0114376e-05,
#             "tagId": "9bd88c88-a2b6-40e2-8e85-5f8fc1e52dae",
#             "tagName": "\uae40\uce58\ucc1c"
#         },
#         {
#             "probability": 7.929769e-05,
#             "tagId": "a7e3e235-771c-43c2-a0f1-9c5c113c02da",
#             "tagName": "\uacc4\ub780\ucc1c"
#         },
#         {
#             "probability": 7.906059e-05,
#             "tagId": "54e4a716-eadf-4fb1-8ca7-e65191926781",
#             "tagName": "\uc21c\ub450\ubd80\ucc0c\uac1c"
#         },
#         {
#             "probability": 7.628829e-05,
#             "tagId": "790cd4c0-c26d-4171-bfcb-140c24384364",
#             "tagName": "\uac10\uc790\ucc44\ubcf6\uc74c"
#         },
#         {
#             "probability": 7.566437e-05,
#             "tagId": "db95afe4-7025-4531-a0c4-c976665a91e1",
#             "tagName": "\uc5f4\ubb34\uad6d\uc218"
#         },
#         {
#             "probability": 7.268519e-05,
#             "tagId": "c6f7b3e4-77f0-4c3a-84f0-d8c2d3673b3a",
#             "tagName": "\uc18c\uc138\uc9c0\ubcf6\uc74c"
#         },
#         {
#             "probability": 7.171175e-05,
#             "tagId": "6726c95c-7229-4896-9336-40c328ff96c0",
#             "tagName": "\uac13\uae40\uce58"
#         },
#         {
#             "probability": 6.542119e-05,
#             "tagId": "b5b35a66-ba78-4cfe-ae0c-aef194092a56",
#             "tagName": "\ub77c\ubcf6\uc774"
#         },
#         {
#             "probability": 6.2249725e-05,
#             "tagId": "b4ed5f62-2f51-4d94-a25b-35036b2c466f",
#             "tagName": "\ucac4\uba74"
#         },
#         {
#             "probability": 6.0484632e-05,
#             "tagId": "c77d6374-5db0-445d-b621-98aa96dee4cf",
#             "tagName": "\uac08\uce58\uc870\ub9bc"
#         },
#         {
#             "probability": 5.644195e-05,
#             "tagId": "73af640d-f2a4-4d17-81e3-7d7bebf286b9",
#             "tagName": "\ucf69\ub098\ubb3c\ubb34\uce68"
#         },
#         {
#             "probability": 5.1383533e-05,
#             "tagId": "7cc436e4-b198-458c-b382-d6f7cbcae48b",
#             "tagName": "\ub77c\uba74"
#         },
#         {
#             "probability": 4.979736e-05,
#             "tagId": "d5aed8b0-99e7-437e-be05-92aed08dde48",
#             "tagName": "\uc813\uac08"
#         },
#         {
#             "probability": 4.971906e-05,
#             "tagId": "c18400e2-2e26-46ed-b4d7-f63759277891",
#             "tagName": "\uaf48\ub9ac\uace0\ucd94\ubb34\uce68"
#         },
#         {
#             "probability": 4.518518e-05,
#             "tagId": "0d4c907e-1886-4ba2-9d13-2daf43317fe9",
#             "tagName": "\ub2ed\uacc4\uc7a5"
#         },
#         {
#             "probability": 3.8959566e-05,
#             "tagId": "c3e49627-fe46-411a-84f6-234280ce5adf",
#             "tagName": "\ubd80\ucd94\uae40\uce58"
#         },
#         {
#             "probability": 3.6404566e-05,
#             "tagId": "7fa351a0-7998-4d2d-80d0-b783e2ce101e",
#             "tagName": "\ub5a1\uaf2c\uce58"
#         },
#         {
#             "probability": 2.9731646e-05,
#             "tagId": "ef625eee-ef88-4cf0-8f04-40f014988601",
#             "tagName": "\ub3c4\ub77c\uc9c0\ubb34\uce68"
#         },
#         {
#             "probability": 2.6570193e-05,
#             "tagId": "710d5fc3-c634-4ab5-85f2-207514938b26",
#             "tagName": "\uc624\uc9d5\uc5b4\ucc44\ubcf6\uc74c"
#         },
#         {
#             "probability": 2.4715508e-05,
#             "tagId": "5ba29caf-39fe-4cc9-9ff1-b30741b57809",
#             "tagName": "\uc6b0\uc5c9\uc870\ub9bc"
#         },
#         {
#             "probability": 2.447637e-05,
#             "tagId": "5f428c71-beff-464f-a5f8-d7418b915d37",
#             "tagName": "\uace0\ucd94\uc7a5\uc9c4\ubbf8\ucc44\ubcf6\uc74c"
#         },
#         {
#             "probability": 2.3970426e-05,
#             "tagId": "13c4217d-bb8d-47a1-8a95-90e611920e7e",
#             "tagName": "\ube44\ube54\ubc25"
#         },
#         {
#             "probability": 1.309395e-05,
#             "tagId": "78aa2480-1f45-46a2-9cfd-dc90fe479057",
#             "tagName": "\uae40\uce58\ucc0c\uac1c"
#         }
#     ]
# }
# ✅ '조개구이' (섭취 칼로리: 234.0 kcal)을 소모하려면:
#      운동이름    운동시간(분)
# 2     줄넘기  15.600000
# 5  계단 오르기  19.500000
# 1     달리기  21.272727
# 3      수영  23.400000
# 7     테니스  23.400000
